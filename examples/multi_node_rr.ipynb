# %% [markdown]
# # Distributed Ridge Regression
# ## Parameter Definition and Centralized Optimization
# The problem is defined as
#
# $$
# \min_{x \in \mathbb{R}^d} \quad \frac{1}{4} \sum_{i = 1}^4 (u_i^\top x - v_i)^2 + \rho \| x \|^2
# $$
#
# where the solution is denoted as $x^*$.

# %%
import numpy as np
import numpy.typing as npt

dim = 10

# Should be consistent with the definition in the graph server
import logging
from topolink import Graph, bootstrap

logging.basicConfig(level=logging.INFO)

L = np.array([[2, -1, 0, -1], [-1, 2, -1, 0], [0, -1, 2, -1], [-1, 0, -1, 2]])
W = np.eye(4) - L * 0.2

graph = Graph.from_mixing_matrix(W, transport="tcp")
n_nodes = graph.number_of_nodes
nodes = [str(i) for i in range(1, n_nodes + 1)]

import numpy.random as npr

npr.seed(0)

rho = 0.01
u = {i: npr.uniform(-1, 1, dim) for i in nodes}
x_tilde = {i: np.multiply(0.1 * (int(i) - 1), np.ones(dim)) for i in nodes}
epsilon = {i: npr.normal(0, 5) for i in nodes}
v = {i: u[i] @ x_tilde[i] + epsilon[i] for i in nodes}

import cvxpy as cp

x = cp.Variable(dim)

loss = cp.sum([(u[i] @ x - v[i]) ** 2 for i in nodes]) / n_nodes
regularizer = rho * cp.sum_squares(x)

prob = cp.Problem(cp.Minimize(loss + regularizer))
prob.solve(cp.OSQP)

x_star: npt.NDArray[np.float64] = x.value  # type: ignore

print(f"Optimal solution: {x_star}")
# Out:
# Optimal solution: [-0.92907018  1.82395728 -2.34861204 -1.14665289 -2.47729986  3.64587729
#   2.57938462 -2.66468855 -3.83712911 -0.87901971]

# %% [markdown]
# ## Benchmarking Distributed Optimization Algorithms
#
# In this section, we benchmark the distributed optimization algorithms `EXTRA`, `NIDS`, `DIGing`, `AugDGM`, `WE`, and `RGT` on the ridge regression problem.
# Each algorithm is executed with its respective step size, and their performance is compared in terms of mean squared error (MSE)
#
# $$
# \frac{1}{4d} \sum_{i = 1}^{4} || x_i - x^* ||^2
# $$
#
# over iterations, where $x_i, x^* \in \mathbb{R}^d$.
#
# The network topology is a ring, and the gossip matrix is defined as $W = I - 0.2L$, with $L$ being the Laplacian matrix of the graph.

# %%
import ray

ray.init(address="auto")


@ray.remote(num_cpus=1)
def ridge_regression(
    node_id: str,
    dimension: int,
    u_i: npt.NDArray[np.float64],
    v_i: npt.NDArray[np.float64],
    rho_i: float,
    gamma: float,
    optimizer_name: str,
) -> npt.NDArray[np.float64]:
    import numpy as np

    max_iter = 2000
    x_i = np.zeros((max_iter, dimension), dtype=np.float64)

    # Define loss function
    def f(var: npt.NDArray[np.float64]) -> npt.NDArray[np.float64]:
        return (u_i @ var - v_i) ** 2 + rho_i * var @ var

    # Define node handle with masking
    from topolink import NodeHandle
    from topolink.transform import GaussianNoise

    tranform = GaussianNoise(scale=0.01)

    nh = NodeHandle(node_id, transform=tranform, transport="tcp")

    # Create optimizer and run iterations
    from dco import get_optimizer

    optimizer = get_optimizer(optimizer_name)(f, nh, gamma)

    optimizer.init(x_i[0])

    for k in range(max_iter - 1):
        x_i[k + 1] = optimizer.step(x_i[k])

    return x_i


try:
    step_sizes = {
        "EXTRA": 0.16,
        "NIDS": 0.21,
        "DIGing": 0.11,
        "AugDGM": 0.31,
        "WE": 0.17,
        "RGT": 0.11,
    }

    local_histories: dict[str, list[npt.NDArray[np.float64]]] = {}

    for alg, gam in step_sizes.items():
        bootstrap(graph)

        refs = [
            ridge_regression.remote(i, dim, u[i], v[i], rho, gam, alg) for i in nodes
        ]
        local_histories[alg] = ray.get(refs)

        print(f"Algorithm: {alg}, Step size: {gam}, Finished!")

finally:
    ray.shutdown()
# Out:
# 2026-02-07 16:31:47,583	INFO util.py:154 -- Missing packages: ['ipywidgets']. Run `pip install -U ipywidgets`, then restart the notebook server for rich notebook output.
# 2026-02-07 16:31:47,596	INFO worker.py:1821 -- Connecting to existing Ray cluster at address: 192.168.1.112:6379...
# 2026-02-07 16:31:47,611	INFO worker.py:1998 -- Connected to Ray cluster. View the dashboard at 127.0.0.1:8265
# /home/rui/code/discoopt/.venv/lib/python3.10/site-packages/ray/_private/worker.py:2046: FutureWarning: Tip: In future versions of Ray, Ray will no longer override accelerator visible devices env var if num_gpus=0 or num_gpus=None (default). To enable this behavior and turn off this error message, set RAY_ACCEL_ENV_VAR_OVERRIDE_ON_ZERO=0
#   warnings.warn(
# INFO:topolink.graph:Graph 'default' running on: 192.168.1.112:44781
# INFO:topolink.discovery:Registered graph service with name 'default'
# INFO:topolink.graph:Node '4' joined graph 'default' from 192.168.1.110:32817.
# INFO:topolink.graph:Node '2' joined graph 'default' from 192.168.1.109:46329.
# INFO:topolink.graph:Node '3' joined graph 'default' from 192.168.1.103:43351.
# INFO:topolink.graph:Node '1' joined graph 'default' from 192.168.1.108:43037.
# INFO:topolink.graph:Graph 'default' registration complete.
# INFO:topolink.graph:Sent neighbor info to all nodes in graph 'default'.
# INFO:topolink.discovery:Unregistered graph service with name 'default'
# INFO:topolink.graph:Graph 'default' running on: 192.168.1.112:45859
# Algorithm: EXTRA, Step size: 0.16, Finished!
# INFO:topolink.discovery:Registered graph service with name 'default'
# INFO:topolink.graph:Node '2' joined graph 'default' from 192.168.1.103:32873.
# INFO:topolink.graph:Node '1' joined graph 'default' from 192.168.1.110:39115.
# INFO:topolink.graph:Node '3' joined graph 'default' from 192.168.1.108:36445.
# INFO:topolink.graph:Node '4' joined graph 'default' from 192.168.1.106:35253.
# INFO:topolink.graph:Graph 'default' registration complete.
# INFO:topolink.graph:Sent neighbor info to all nodes in graph 'default'.
# INFO:topolink.discovery:Unregistered graph service with name 'default'
# INFO:topolink.graph:Graph 'default' running on: 192.168.1.112:45719
# Algorithm: NIDS, Step size: 0.21, Finished!
# INFO:topolink.discovery:Registered graph service with name 'default'
# INFO:topolink.graph:Node '4' joined graph 'default' from 192.168.1.110:42773.
# INFO:topolink.graph:Node '3' joined graph 'default' from 192.168.1.108:35177.
# INFO:topolink.graph:Node '2' joined graph 'default' from 192.168.1.103:34213.
# INFO:topolink.graph:Node '1' joined graph 'default' from 192.168.1.106:37439.
# INFO:topolink.graph:Graph 'default' registration complete.
# INFO:topolink.graph:Sent neighbor info to all nodes in graph 'default'.
# INFO:topolink.discovery:Unregistered graph service with name 'default'
# ---------------------------------------------------------------------------
# RayTaskError(ValueError)                  Traceback (most recent call last)
# Cell In[2], line 64
#      59         bootstrap(graph)
#      61         refs = [
#      62             ridge_regression.remote(i, dim, u[i], v[i], rho, gam, alg) for i in nodes
#      63         ]
# ---> 64         local_histories[alg] = ray.get(refs)
#      66         print(f"Algorithm: {alg}, Step size: {gam}, Finished!")
#      68 finally:
#
# File ~/code/discoopt/.venv/lib/python3.10/site-packages/ray/_private/auto_init_hook.py:22, in wrap_auto_init.<locals>.auto_init_wrapper(*args, **kwargs)
#      19 @wraps(fn)
#      20 def auto_init_wrapper(*args, **kwargs):
#      21     auto_init_ray()
# ---> 22     return fn(*args, **kwargs)
#
# File ~/code/discoopt/.venv/lib/python3.10/site-packages/ray/_private/client_mode_hook.py:104, in client_mode_hook.<locals>.wrapper(*args, **kwargs)
#     102     if func.__name__ != "init" or is_client_mode_enabled_by_default:
#     103         return getattr(ray, func.__name__)(*args, **kwargs)
# --> 104 return func(*args, **kwargs)
#
# File ~/code/discoopt/.venv/lib/python3.10/site-packages/ray/_private/worker.py:2967, in get(object_refs, timeout, _tensor_transport)
#    2961 if not isinstance(object_refs, list):
#    2962     raise ValueError(
#    2963         f"Invalid type of object refs, {type(object_refs)}, is given. "
#    2964         "'object_refs' must either be an ObjectRef or a list of ObjectRefs. "
#    2965     )
# -> 2967 values, debugger_breakpoint = worker.get_objects(
#    2968     object_refs, timeout=timeout, _tensor_transport=_tensor_transport
#    2969 )
#    2970 for i, value in enumerate(values):
#    2971     if isinstance(value, RayError):
#    2972         # If the object was lost and it wasn't due to owner death, it may be
#    2973         # because the object store is full and objects needed to be evicted.
#
# File ~/code/discoopt/.venv/lib/python3.10/site-packages/ray/_private/worker.py:1015, in Worker.get_objects(self, object_refs, timeout, return_exceptions, skip_deserialization, _tensor_transport)
#    1013     global_worker.core_worker.log_plasma_usage()
#    1014 if isinstance(value, RayTaskError):
# -> 1015     raise value.as_instanceof_cause()
#    1016 else:
#    1017     raise value
#
# RayTaskError(ValueError): ray::ridge_regression() (pid=1919, ip=192.168.1.110)
#   File "/tmp/ipykernel_40573/842254300.py", line 41, in ridge_regression
#   File "/home/turtlebot/distributed_ws/discoopt/src/dco/optimizer.py", line 297, in step
#     w_y_i = self._ops.weighted_mix(self._aux_var["y_i"])
#   File "/home/turtlebot/distributed_ws/topolink/src/topolink/node_handle.py", line 338, in weighted_mix
#     mixed_state = state * self._weight + sum(
# ValueError: operands could not be broadcast together with shapes (10,) (20,)

# %% [markdown]
# ## Plot results

# %%
if __name__ == "__main__":
    import matplotlib.pyplot as plt
    from numpy import mean, stack

    plt.rcParams["text.usetex"] = True
    plt.rcParams["font.family"] = "serif"

    plt.rcParams.update(
        {
            "font.size": 14,
            "axes.titlesize": 16,
            "axes.labelsize": 16,
            "xtick.labelsize": 16,
            "ytick.labelsize": 16,
            "legend.fontsize": 13,
        }
    )

    fig, ax = plt.subplots()

    line_options = {"linewidth": 3, "linestyle": "--"}

    hh: list[npt.NDArray[np.float64]] = []

    for algorithm, histories in local_histories.items():
        # shape: (n_nodes, n_iter, dim)
        stacked_histories = stack(histories)
        # shape: (n_nodes, n_iter)
        mse_evolution_nodes = mean((stacked_histories - x_star) ** 2, axis=2)
        mse_evolution = mean(mse_evolution_nodes, axis=0)
        ax.semilogy(mse_evolution, label=algorithm, **line_options)
        hh.append(mse_evolution)

    ax.set_xlim((0, 2000))
    ax.set_xlabel("iterations $k$")
    ax.set_ylabel("MSE")
    ax.legend(loc=(0.7, 0.28))
    ax.grid(True, which="major", linestyle="-", linewidth=0.8)
